# %% [markdown]
# # 4 Joint analysis
# ## 4.1 Joint analysis of three MuSCAT nights of TOI 263.01 observations
#
# Here we combine the light curves from the three nights of previously reduced MuSCAT2 observations.

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from pytransit.orbits import epoch

# %%
# %run src/m2lpf.py

# %%
lpf = M2LPF('toi_263_m2_ldtk', use_ldtk=True)

# %%
lpf.optimize_global(niter=5000, npop=250)
# Out:
# HBox(children=(IntProgress(value=0, description='Global optimisation', max=5000, style=ProgressStyle(descripti…

# %%
fig = lpf.plot_light_curves(figsize=(14,5), width=2);
setp(fig.axes, ylim=(0.92, 1.05));

# %%
fig, axs = subplots(3, 3, figsize=(14,5), constrained_layout=True, sharex='all', sharey='all')
fmodel = squeeze(lpf.flux_model(lpf.de.minimum_location))
t0, p = lpf.de.minimum_location[0], lpf.de.minimum_location[1]
for i,ax in enumerate(axs.T.flat):
    t = lpf.times[i]
    e = epoch(t.mean(), t0, p)
    tc = t0 + e*p
    ax.plot(t-tc, lpf.fluxes[i], 'k.', alpha=0.2)
    ax.plot(t-tc, fmodel[lpf.lcslices[i]], 'k');
    setp(ax, xlim=(-1/24, 1/24))
setp(axs, ylim=(0.92, 1.05));

# %%
lpf.sample_mcmc(5000, thin=50, repeats=5, save=True)
# Out:
# HBox(children=(IntProgress(value=0, description='MCMC sampling', max=5, style=ProgressStyle(description_width=…
# HBox(children=(IntProgress(value=0, description='Run 1/5', max=5000, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Run 2/5', max=5000, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Run 3/5', max=5000, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Run 4/5', max=5000, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Run 5/5', max=5000, style=ProgressStyle(description_width='in…

# %%
lpf.sample_mcmc(10000, thin=100, repeats=5, save=True)
# Out:
# HBox(children=(IntProgress(value=0, description='MCMC sampling', max=5, style=ProgressStyle(description_width=…
# HBox(children=(IntProgress(value=0, description='Run 1/5', max=10000, style=ProgressStyle(description_width='i…
# HBox(children=(IntProgress(value=0, description='Run 2/5', max=10000, style=ProgressStyle(description_width='i…
# HBox(children=(IntProgress(value=0, description='Run 3/5', max=10000, style=ProgressStyle(description_width='i…
# HBox(children=(IntProgress(value=0, description='Run 4/5', max=10000, style=ProgressStyle(description_width='i…
# HBox(children=(IntProgress(value=0, description='Run 5/5', max=10000, style=ProgressStyle(description_width='i…

# %%
df = lpf.posterior_samples(derived_parameters=False)
fig, axs = subplots(3, 3, figsize=(14,6), constrained_layout=True, sharex='all', sharey='all')
fmodel = lpf.flux_model(permutation(df.values)[:1000])
fmperc = percentile(fmodel, [50, 16, 84, 0.5, 99.5], 0)

t0, p = lpf.de.minimum_location[0], lpf.de.minimum_location[1]
for i,ax in enumerate(axs.T.flat):
    t = lpf.times[i]
    e = epoch(t.mean(), t0, p)
    tc = t0 + e*p
    ax.fill_between(t-tc, *fmperc[3:5, lpf.lcslices[i]], alpha=0.15)
    ax.fill_between(t-tc, *fmperc[1:3, lpf.lcslices[i]], alpha=0.25)
    ax.plot(t-tc, fmperc[0, lpf.lcslices[i]])
    ax.plot(t-tc, lpf.fluxes[i], 'k.', alpha=0.2)
    setp(ax, xlim=(-1/24, 1/24))
setp(axs, ylim=(0.92, 1.05));

# %% [markdown]
# ---
#
#
# <center> © 2019 Hannu Parviainen </center>
