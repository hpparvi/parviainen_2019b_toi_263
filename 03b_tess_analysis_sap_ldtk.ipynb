# %% [markdown]
# # 3 TESS light curve analysis
# ## 3.2 SAP flux and LDTk

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from corner import corner

# %%
# %run src/core.py
# %run src/ctesslpf.py

# %%
lpf = CTESSLPF('toi_263_tess_sap_ldtk', 'sap', use_ldtk=True)

# %%
lpf.optimize_global(7500, 400)
# Out:
# HBox(children=(IntProgress(value=0, description='Global optimisation', max=7500, style=ProgressStyle(descripti…

# %%
lpf.plot_folded_transit(ylim=(0.94,1.025), binwidth=4)

# %%
lpf.sample_mcmc(5000, thin=50, repeats=5, save=True)
# Out:
# HBox(children=(IntProgress(value=0, description='MCMC sampling', max=5, style=ProgressStyle(description_width=…
# HBox(children=(IntProgress(value=0, description='Run 1/5', max=5000, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Run 2/5', max=5000, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Run 3/5', max=5000, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Run 4/5', max=5000, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Run 5/5', max=5000, style=ProgressStyle(description_width='in…

# %%
lpf.sample_mcmc(10000, thin=100, repeats=2, save=True)
# Out:
# HBox(children=(IntProgress(value=0, description='MCMC sampling', max=2, style=ProgressStyle(description_width=…
# HBox(children=(IntProgress(value=0, description='Run 1/2', max=10000, style=ProgressStyle(description_width='i…
# HBox(children=(IntProgress(value=0, description='Run 2/2', max=10000, style=ProgressStyle(description_width='i…

# %%
corner(lpf.posterior_samples(derived_parameters=False).iloc[:,:6]);

# %%
def plot_folded_transit(self, method='de', figsize=(13, 6), ylim=(0.9975, 1.002), xlim=None, binwidth=8):
    if method == 'de':
        pv = self.de.minimum_location
        tc, p = pv[[0, 1]]
    else:
        pv = self.posterior_samples(include_ldc=True).median().values
        tc, p = pv[[0, 1]]

    phase = p * fold(self.timea, p, tc, 0.5)
    binwidth = binwidth / 24 / 60
    sids = argsort(phase)

    tm = self.transit_model(pv)
    bl = squeeze(self.baseline(pv))

    bp, bfo, beo = downsample_time(phase[sids], (self.ofluxa / bl)[sids], binwidth)

    fig, ax = subplots(figsize=figsize)
    ax.plot(phase - 0.5 * p, self.ofluxa / bl, '.', alpha=0.15)
    ax.errorbar(bp - 0.5 * p, bfo, beo, fmt='ko')
    ax.plot(phase[sids] - 0.5 * p, tm[sids], 'k')
    xlim = xlim if xlim is not None else 1.01 * (bp[isfinite(bp)][[0, -1]] - 0.5 * p)
    setp(ax, ylim=ylim, xlim=xlim, xlabel='Time - Tc [d]', ylabel='Normalised flux')
    fig.tight_layout()

# %%
lpf.plot_folded_transit('mc', ylim=(0.9,1.1), binwidth=4)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-26-4a348ef93ea4> in <module>
# ----> 1 lpf.plot_folded_transit('mc', ylim=(0.9,1.1), binwidth=4)
#
# ~/soft/anaconda/lib/python3.7/site-packages/PyTransit-2.0-py3.7.egg/pytransit/lpf/tesslpf.py in plot_folded_transit(self, method, figsize, ylim, xlim, binwidth)
#      97             tc, p = pv[[0, 1]]
#      98         else:
# ---> 99             raise NotImplementedError
#     100
#     101         phase = p * fold(self.timea, p, tc, 0.5)
#
# NotImplementedError:

# %%
plot_folded_transit(lpf, 'mc', ylim=(0.9,1.1), binwidth=4)

# %%
hist(1 - df.k2_app / df.k2_true);

# %%
df = lpf.posterior_samples()
sqrt(df.k2_app).hist()

# %%
lpf.plot_individual_transits(ncols=5, figsize=(14,15));

# %%
cbl = [n for n in lpf.ps.names if 'bls' in n]
cbi = [n for n in lpf.ps.names if 'bli' in n]
cer = [n for n in lpf.ps.names if 'lne' in n]

# %%
df = lpf.posterior_samples(include_ldc=True)
fig, axs = subplots(2, 1, figsize=(13,8), sharex=True)
sb.violinplot(data=df[cbi][::10], inner=None, ax=axs[0])
sb.violinplot(data=df[cbl][::10], inner=None, ax=axs[1])
#sb.violinplot(data=10**df[cer][::10], inner=None, ax=axs[2])
fig.tight_layout()
