# %% [markdown]
# # 2 LCO light curve analysis
# ## 2.2 Physical contamination model
#
# This notebook repeats the previous LCO analysis allowing for light contamination from an unresolved contaminating source. The only major difference are that the LPF is based on `pytransit.lpf.cntlpf.PhysContLPF`, we need to define the intstrument, and we set an informative prior on the effective temperature of the host.

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %run src/lcolpf.py

# %%
lpf = LCOLPF('toi_263_lco', use_ldtk=False)

# %%
lpf.optimize_global(3500, npop=100)

# %%
lpf.plot_light_curves('de', figsize=(13,3), width=2.5);

# %%
lpf.sample_mcmc(5000, thin=50, repeats=5, save=True)

# %%
lpf.sample_mcmc(10000, thin=100, repeats=5, save=True)

# %%
lpf.plot_light_curves('mcmc', figsize=(13,3));

# %% [markdown]
# ---
#
# <center> © 2019 Hannu Parviainen </center>
